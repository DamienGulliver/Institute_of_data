# %% [markdown]
# <a href="https://colab.research.google.com/github/DamienGulliver/Institute_of_data/blob/main/capstone_train_efficientB3_TPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages

import datetime
import re
import os
from os import listdir
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import keras
from keras import Input, Model, Sequential
from keras.callbacks import LearningRateScheduler
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.losses import BinaryCrossentropy
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.efficientnet import EfficientNetB3
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.8.0

# %%
# Check RAM of runtime (should be >20gb)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('')
# Out:
# Your runtime has 37.8 gigabytes of available RAM

# %%
# define environment variables

PROJECT_ID = 'effnet-moa'
BUCKET_NAME = 'effnet-moa'
IMAGE_SIZE = 300
CHANNELS = 3
EPOCHS = 100
N_TRAIN = 13265
N_VALID = 3316
N_TEST = 7107
N_CLASSES = 185
BATCH_SIZE = 256
TRAIN_STEPS = N_TRAIN // BATCH_SIZE
AUTO = tf.data.experimental.AUTOTUNE 
GCS_PATTERN = 'gs://effnet-moa/capstone_preprocessed_data/res300_batchsize_256/*.tfrecords'
TF_HUB_MODEL_URL = "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b3/feature_vector/2" # effnetb0_v2 trained on imagenet-21k
feature_extractor = hub.KerasLayer(TF_HUB_MODEL_URL, input_shape=(IMAGE_SIZE,IMAGE_SIZE,CHANNELS))

# %%
# Initialise TPU

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Running on TPU  ['10.12.129.2:8470']
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.12.129.2:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.12.129.2:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
# Set up google credentials to access GCS bucket

from google.colab import auth
auth.authenticate_user()

# !gcloud config set project {PROJECT_ID}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://effnet-moa/

# %%
# functions to parse tfrecords and load dataset

def get_filenames(file_path=GCS_PATTERN, train_substring=None, val_substring=None, test_substring=None):
  
  filenames = tf.io.gfile.glob(file_path)
  train_str = [train_substring]
  val_str = [val_substring]
  test_str = [test_substring]

  def Filter(string, substr):
    return [str for str in string if
             any(sub in str for sub in substr)]
  
  train_fns = Filter(filenames, train_str)
  validation_fns = Filter(filenames, val_str)
  test_fns = Filter(filenames, test_str)

  return train_fns, validation_fns, test_fns

def parse_tfrecord(element):
  data = {
      'height': tf.io.FixedLenFeature([], tf.int64),
      'width':tf.io.FixedLenFeature([], tf.int64),
      'depth':tf.io.FixedLenFeature([], tf.int64),
      'raw_image' : tf.io.FixedLenFeature([], tf.string),
      'label': tf.io.FixedLenFeature([], tf.string),
    }

  content = tf.io.parse_single_example(element, data)
  
  height = content['height']
  width = content['width']
  depth = content['depth']
  label = content['label']
  raw_image = content['raw_image']
  
  #get image and label, reshape it appropriately
  feature = tf.io.parse_tensor(raw_image, out_type=tf.float32)
  feature = tf.reshape(feature, shape=[height,width,depth])
  label = tf.io.parse_tensor(label, out_type=tf.float32)
  label = tf.reshape(label, shape=[185])  
  return (feature, label)

# Read from TFRecords
def load_dataset(filenames):
  records = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO)
  return records.map(parse_tfrecord, num_parallel_calls=AUTO)

# %%
# Get train, validation and test filenames

train_fns, validation_fns, test_fns = get_filenames(
    train_substring='train_ds_256', 
    val_substring='val_ds_256', 
    test_substring='test_ds_256'
    )

# %%
#  create load_dataset objects to be batched into model during training

train_ds = load_dataset(train_fns).repeat().shuffle(2048).batch(BATCH_SIZE).prefetch(AUTO)
val_ds = load_dataset(validation_fns).batch(BATCH_SIZE).prefetch(AUTO)
test_ds = load_dataset(test_fns).batch(BATCH_SIZE).prefetch(AUTO)

# %%
# Functions to show loaded data integrity

def display_one_image(image, title, subplot, color):
  plt.subplot(subplot)
  plt.axis('off')
  plt.imshow(image)
  plt.title(title, fontsize=16, color=color)
  
def display_nine_images(images, titles, title_colors=None):
  subplot = 331
  plt.figure(figsize=(13,13))
  for i in range(9):
    color = 'black' if title_colors is None else title_colors[i]
    display_one_image(images[i], titles[i], 331+i, color)
  plt.tight_layout()
  plt.subplots_adjust(wspace=0.1, hspace=0.1)
  plt.show()

def get_dataset_iterator(dataset, n_examples):
  return dataset.unbatch().batch(n_examples).as_numpy_iterator()

train_sample_iterator = get_dataset_iterator(train_ds, 3)

# %%
# Re-run this cell to show a new batch of images

images, classes = next(train_sample_iterator)
class_idxs = np.argmax(classes, axis=-1) # transform from one-hot array to class number
labels = [np.arange(185).tolist()[idx] for idx in class_idxs]
display_nine_images(images, labels)

# %%
def create_model(classes=N_CLASSES):

  base_model = EfficientNetB3(
      input_shape=(IMAGE_SIZE,IMAGE_SIZE,CHANNELS), 
      weights='imagenet', 
      include_top=False)
  
  inputs = keras.Input(shape=(IMAGE_SIZE,IMAGE_SIZE,CHANNELS))
  x = base_model(inputs)
  x.trainable = True
  x = GlobalAveragePooling2D()(x)
  x = Dropout(0.2)(x)
  outputs = Dense(N_CLASSES, activation='sigmoid')(x)
  model = keras.Model(inputs, outputs)

  model.compile(
    optimizer='adam',
    loss = 'binary_crossentropy',
    metrics=['accuracy']
  )
  
  return model

# %%
# creating the model within the TPUStrategy scope to utilise TPU

with tpu_strategy.scope(): 
  model = create_model()
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step
# 43950080/43941136 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  efficientnetb3 (Functional)  (None, 10, 10, 1536)     10783535
#
#  global_average_pooling2d_1   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 185)               284345
#
# =================================================================
# Total params: 11,067,880
# Trainable params: 10,980,577
# Non-trainable params: 87,303
# _________________________________________________________________
# None

# %%
print("TRAINING IMAGES: ", N_TRAIN, ", STEPS PER EPOCH: ", TRAIN_STEPS)
print("VALIDATION IMAGES: ", N_VALID)
# Out:
# TRAINING IMAGES:  13265 , STEPS PER EPOCH:  51
# VALIDATION IMAGES:  3316

# %%
def train_model(model=None, data=train_ds, val=val_ds, epochs=EPOCHS, train_steps=TRAIN_STEPS, batch_size=BATCH_SIZE):

  # define learning rates for learning rate scheduler
  start_lr = 0.00001
  min_lr = 0.00001
  max_lr = 0.00005 * tpu_strategy.num_replicas_in_sync
  rampup_epochs = 5
  sustain_epochs = 0
  exp_decay = .8

  # function for lr_callback
  def lrfn(epoch):
    if epoch < rampup_epochs:
      return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
      return max_lr
    else:
      return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr

  # define callbacks
  lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=True)

  # fit model
  history = model.fit(data,
                      batch_size=BATCH_SIZE, 
                      validation_data=val, 
                      steps_per_epoch=train_steps, 
                      epochs=epochs, 
                      callbacks=[lr_callback])
  
  def display_training_curves(training, validation, title, subplot):
    ax = plt.subplot(subplot)
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    ax.set_xlabel('epoch')
    ax.legend(['training', 'validation'])

  plt.subplots(figsize=(10,10))
  plt.tight_layout()

  display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
  display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)
  
  plt.savefig('training_curves.svg')
  
  return history

# %%
train_model(model)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 1/100
# 51/51 [==============================] - 267s 3s/step - loss: 0.6468 - accuracy: 0.0087 - val_loss: 0.6990 - val_accuracy: 3.0157e-04 - lr: 1.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 8
 1.0000e-05
#
# Epoch 82: LearningRateScheduler setting learning rate to 1.0000016823006722e-05.
# Epoch 82/100
# 51/51 [==============================] - 124s 2s/step - loss: 0.0170 - accuracy: 0.2108 - val_loss: 0.0214 - val_accuracy: 0.1378 - lr: 1.0000e-05
#
# Epoch 83: LearningRateScheduler setting learning rate to 1.0000013458405378e-05.
# Epoch 83/100
# 51/51 [==============================] - 124s 2s/step - loss: 0.0169 - accuracy: 0.2125 - val_loss: 0.0213 - val_accuracy: 0.1182 - lr: 1.0000e-05
#
# Epoch 84: LearningRateScheduler setting learning rate to 1.0000010766724302e-05.
# Epoch 84/100
# 51/51 [==============================] - 126s 3s/step - loss: 0.0168 - accuracy: 0.2103 - val_loss: 0.0270 - val_accuracy: 0.0796 - lr: 1.0000e-05
#
# Epoch 85: LearningRateScheduler setting learning rate to 1.0000008613379442e-05.
# Epoch 85/100
# 51/51 [==============================] - 116s 2s/step - loss: 0.0168 - accuracy: 0.2152 - val_loss: 0.0204 - val_accuracy: 0.1638 - lr: 1.0000e-05
#
# Epoch 86: LearningRateScheduler setting learning rate to 1.0000006890703554e-05.
# Epoch 86/100
# 51/51 [==============================] - 114s 2s/step - loss: 0.0168 - accuracy: 0.2121 - val_loss: 0.0233 - val_accuracy: 0.1248 - lr: 1.0000e-05
#
# Epoch 87: LearningRateScheduler setting learning rate to 1.0000005512562843e-05.
# Epoch 87/100
# 51/51 [==============================] - 113s 2s/step - loss: 0.0168 - accuracy: 0.2120 - val_loss: 0.1125 - val_accuracy: 0.0341 - lr: 1.0000e-05
#
# Epoch 88: LearningRateScheduler setting learning rate to 1.0000004410050274e-05.
# Epoch 88/100
# 51/51 [==============================] - 121s 2s/step - loss: 0.0166 - accuracy: 0.2183 - val_loss: 0.0521 - val_accuracy: 0.0302 - lr: 1.0000e-05
#
# Epoch 89: LearningRateScheduler setting learning rate to 1.000000352804022e-05.
# Epoch 89/100
# 51/51 [==============================] - 117s 2s/step - loss: 0.0168 - accuracy: 0.2089 - val_loss: 0.0241 - val_accuracy: 0.0932 - lr: 1.0000e-05
#
# Epoch 90: LearningRateScheduler setting learning rate to 1.0000002822432176e-05.
# Epoch 90/100
# 51/51 [==============================] - 113s 2s/step - loss: 0.0166 - accuracy: 0.2162 - val_loss: 0.0210 - val_accuracy: 0.1252 - lr: 1.0000e-05
#
# Epoch 91: LearningRateScheduler setting learning rate to 1.000000225794574e-05.
# Epoch 91/100
# 51/51 [==============================] - 109s 2s/step - loss: 0.0166 - accuracy: 0.2132 - val_loss: 0.0285 - val_accuracy: 0.0796 - lr: 1.0000e-05
#
# Epoch 92: LearningRateScheduler setting learning rate to 1.0000001806356592e-05.
# Epoch 92/100
# 51/51 [==============================] - 111s 2s/step - loss: 0.0167 - accuracy: 0.2118 - val_loss: 0.0529 - val_accuracy: 0.0703 - lr: 1.0000e-05
#
# Epoch 93: LearningRateScheduler setting learning rate to 1.0000001445085275e-05.
# Epoch 93/100
# 51/51 [==============================] - 108s 2s/step - loss: 0.0165 - accuracy: 0.2162 - val_loss: 0.0251 - val_accuracy: 0.0814 - lr: 1.0000e-05
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.000000115606822e-05.
# Epoch 94/100
# 51/51 [==============================] - 105s 2s/step - loss: 0.0165 - accuracy: 0.2176 - val_loss: 0.0289 - val_accuracy: 0.0908 - lr: 1.0000e-05
#
# Epoch 95: LearningRateScheduler setting learning rate to 1.0000000924854576e-05.
# Epoch 95/100
# 51/51 [==============================] - 110s 2s/step - loss: 0.0165 - accuracy: 0.2184 - val_loss: 0.8838 - val_accuracy: 9.0470e-04 - lr: 1.0000e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 1.0000000739883661e-05.
# Epoch 96/100
# 51/51 [==============================] - 100s 2s/step - loss: 0.0165 - accuracy: 0.2208 - val_loss: 0.0311 - val_accuracy: 0.0796 - lr: 1.0000e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.000000059190693e-05.
# Epoch 97/100
# 51/51 [==============================] - 119s 2s/step - loss: 0.0165 - accuracy: 0.2196 - val_loss: 0.0278 - val_accuracy: 0.0926 - lr: 1.0000e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 1.0000000473525544e-05.
# Epoch 98/100
# 51/51 [==============================] - 115s 2s/step - loss: 0.0164 - accuracy: 0.2227 - val_loss: 0.0263 - val_accuracy: 0.0826 - lr: 1.0000e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 1.0000000378820435e-05.
# Epoch 99/100
# 51/51 [==============================] - 106s 2s/step - loss: 0.0163 - accuracy: 0.2194 - val_loss: 0.0283 - val_accuracy: 0.1001 - lr: 1.0000e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.0000000303056348e-05.
# Epoch 100/100
# 51/51 [==============================] - 116s 2s/step - loss: 0.0164 - accuracy: 0.2219 - val_loss: 0.0287 - val_accuracy: 0.0995 - lr: 1.0000e-05

# %%
# Evaluate the model on the test dataset

results = model.evaluate(test_ds, batch_size=BATCH_SIZE)
print("test loss, test acc:", results)
# Out:
# 28/28 [==============================] - 39s 817ms/step - loss: 0.0286 - accuracy: 0.1045
# test loss, test acc: [0.02859451249241829, 0.10454481840133667]

# %%
# Save trained model
model.save('effnetb3_imagenet_bs256.h5')

# upload trained model to GCS bucket
# !gsutil -m cp /content/effnetb3_imagenet_bs256.h5 gs://{BUCKET_NAME}/capstone_trained_models/
# Out:
# Copying file:///content/effnetb3_noisy_student_bs256.h5 [Content-Type=application/octet-stream]...
# -
# Operation completed over 1 objects/127.4 MiB.

# %%
# upload training curves to GCS bucket
# !gsutil -m cp /content/training_curves.svg gs://{BUCKET_NAME}/capstone_trained_models/
# Out:
# Copying file:///content/training_curves.svg [Content-Type=image/svg+xml]...
# / [1/1 files][ 48.0 KiB/ 48.0 KiB] 100% Done
# Operation completed over 1 objects/48.0 KiB.

# %%
# Predict classes
predictions = model.predict(test_ds, batch_size=BATCH_SIZE)
print("predictions shape:", predictions.shape)
# Out:
# predictions shape: (7107, 185)

# %%
# Create empty dataframe to append predictions to
cols = np.arange(185).tolist()
preds_df = pd.DataFrame(columns=cols)

# Append predictions to dataframe
for pred in predictions:
  preds_df = preds_df.append(pd.DataFrame(pred.reshape(1,-1), columns=cols), ignore_index=True)

# Convert dataframe to csv file
preds_df.to_csv('effnetb3_imagenet_bs256_predictions')

# %%
# upload predictions to GCS bucket
# !gsutil -m cp /content/effnetb3_noisy_student_bs256_predictions.csv gs://{BUCKET_NAME}/capstone_results/
# Out:
# CommandException: No URLs matched: /content/effnetb3_noisy_student_bs256_predictions.csv
# CommandException: 1 file/object could not be transferred.

# %%
x = preds_df.values
print('MIN pred',np.min(x),'MAX pred',np.max(x))
plt.figure(figsize=(20,4))
plt.subplot(1,2,1)
plt.hist( x[x<0.2], bins=50)
plt.subplot(1,2,2)
plt.hist( x[x>0.8], bins=50)
plt.show()
# Out:
# MIN pred 0.00028783083 MAX pred 0.95513284

# %%
from google.colab import files

# %%
plt.figure(figsize=(10,6))
plt.hist(x[x>0.1], bins=50)
plt.gca().set_title('Predicted Class Probabilities', fontsize=14)

plt.savefig('class_probabilities.svg', bbox='tight')

files.download('class_probabilities.svg')
